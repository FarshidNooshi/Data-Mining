# %% [markdown]
# <div align="center">
# <h1>In The Name Of GOD</h1>
# </div>

# %% [markdown]
# # HW1 - Data Mining
#
# ## 1. Overfitting

# %% [markdown]
# ### 1.1. Overfitting in Linear Regression

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# Read the data from the file `IMDB-Movie-Data.csv` and store it in a pandas DataFrame.

# %%
df = pd.read_csv("IMDB-Movie-Data.csv") 

df.head(10)
# Out:
#    Rank                    Title                       Genre  \
# 0     1  Guardians of the Galaxy     Action,Adventure,Sci-Fi
# 1     2               Prometheus    Adventure,Mystery,Sci-Fi
# 2     3                    Split             Horror,Thriller
# 3     4                     Sing     Animation,Comedy,Family
# 4     5            Suicide Squad    Action,Adventure,Fantasy
# 5     6           The Great Wall    Action,Adventure,Fantasy
# 6     7               La La Land          Comedy,Drama,Music
# 7     8                 Mindhorn                      Comedy
# 8     9       The Lost City of Z  Action,Adventure,Biography
# 9    10               Passengers     Adventure,Drama,Romance
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
# 5  European mercenaries searching for black powde...           Yimou Zhang
# 6  A jazz pianist falls for an aspiring actress i...       Damien Chazelle
# 7  A has-been actor best known for playing the ti...            Sean Foley
# 8  A true-life drama, centering on British explor...            James Gray
# 9  A spacecraft traveling to a distant colony pla...         Morten Tyldum
#
#                                               Actors  Year  Runtime (Minutes)  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014                121
# 1  Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012                124
# 2  James McAvoy, Anya Taylor-Joy, Haley Lu Richar...  2016                117
# 3  Matthew McConaughey,Reese Witherspoon, Seth Ma...  2016                108
# 4  Will Smith, Jared Leto, Margot Robbie, Viola D...  2016                123
# 5      Matt Damon, Tian Jing, Willem Dafoe, Andy Lau  2016                103
# 6  Ryan Gosling, Emma Stone, Rosemarie DeWitt, J....  2016                128
# 7  Essie Davis, Andrea Riseborough, Julian Barrat...  2016                 89
# 8  Charlie Hunnam, Robert Pattinson, Sienna Mille...  2016                141
# 9  Jennifer Lawrence, Chris Pratt, Michael Sheen,...  2016                116
#
#    Rating   Votes  Revenue (Millions)  Metascore
# 0     8.1  757074              333.13       76.0
# 1     7.0  485820              126.46       65.0
# 2     7.3  157606              138.12       62.0
# 3     7.2   60545              270.32       59.0
# 4     6.2  393727              325.02       40.0
# 5     6.1   56036               45.13       42.0
# 6     8.3  258682              151.06       93.0
# 7     6.4    2490                 NaN       71.0
# 8     7.1    7188                8.01       78.0
# 9     7.0  192177              100.01       41.0

# %% [markdown]
# From the information of the DataFrame, we can see that the `Revenue (Millions)` and `Metascore` columns have missing values. We can fill the missing values with the mean of the column.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %% [markdown]
# Finding rows with two or more missing values. We can see that there are 30 rows with two or more missing values.

# %%
target_rows = df[df.isnull().sum(axis=1) >= 2]

print(target_rows.shape)
# Out:
# (30, 12)

# %% [markdown]
# Drop the rows with two or more missing values.

# %%
df.drop(target_rows.index, inplace=True)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 970 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                970 non-null    int64
#  1   Title               970 non-null    object
#  2   Genre               970 non-null    object
#  3   Description         970 non-null    object
#  4   Director            970 non-null    object
#  5   Actors              970 non-null    object
#  6   Year                970 non-null    int64
#  7   Runtime (Minutes)   970 non-null    int64
#  8   Rating              970 non-null    float64
#  9   Votes               970 non-null    int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 98.5+ KB

# %% [markdown]
# Replacing the missing values of the `Revenue (Millions)` column with the mean of the column.

# %%
df['Revenue (Millions)'].fillna(df['Revenue (Millions)'].mean(), inplace=True)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 970 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                970 non-null    int64
#  1   Title               970 non-null    object
#  2   Genre               970 non-null    object
#  3   Description         970 non-null    object
#  4   Director            970 non-null    object
#  5   Actors              970 non-null    object
#  6   Year                970 non-null    int64
#  7   Runtime (Minutes)   970 non-null    int64
#  8   Rating              970 non-null    float64
#  9   Votes               970 non-null    int64
#  10  Revenue (Millions)  970 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 98.5+ KB

# %% [markdown]
# Sorting the DataFrame by the `Rating` column and correcting the rank of the rows.

# %%
# Sort the dataframe by the 'Rating' column in descending order
df.sort_values(by='Rating', ascending=False, inplace=True)

df.head(10)
# Out:
#      Rank                  Title                    Genre  \
# 54     55        The Dark Knight       Action,Crime,Drama
# 117   118                 Dangal   Action,Biography,Drama
# 80     81              Inception  Action,Adventure,Sci-Fi
# 36     37           Interstellar   Adventure,Drama,Sci-Fi
# 96     97          Kimi no na wa  Animation,Drama,Fantasy
# 249   250       The Intouchables   Biography,Comedy,Drama
# 64     65           The Prestige     Drama,Mystery,Sci-Fi
# 991   992       Taare Zameen Par       Drama,Family,Music
# 476   477    The Lives of Others           Drama,Thriller
# 124   125  The Dark Knight Rises          Action,Thriller
#
#                                            Description  \
# 54   When the menace known as the Joker wreaks havo...
# 117  Former wrestler Mahavir Singh Phogat and his t...
# 80   A thief, who steals corporate secrets through ...
# 36   A team of explorers travel through a wormhole ...
# 96   Two strangers find themselves linked in a biza...
# 249  After he becomes a quadriplegic from a paragli...
# 64   Two stage magicians engage in competitive one-...
# 991  An eight-year-old boy is thought to be a lazy ...
# 476  In 1984 East Berlin, an agent of the secret po...
# 124  Eight years after the Joker's reign of anarchy...
#
#                              Director  \
# 54                  Christopher Nolan
# 117                     Nitesh Tiwari
# 80                  Christopher Nolan
# 36                  Christopher Nolan
# 96                     Makoto Shinkai
# 249                   Olivier Nakache
# 64                  Christopher Nolan
# 991                        Aamir Khan
# 476  Florian Henckel von Donnersmarck
# 124                 Christopher Nolan
#
#                                                 Actors  Year  \
# 54   Christian Bale, Heath Ledger, Aaron Eckhart,Mi...  2008
# 117  Aamir Khan, Sakshi Tanwar, Fatima Sana Shaikh,...  2016
# 80   Leonardo DiCaprio, Joseph Gordon-Levitt, Ellen...  2010
# 36   Matthew McConaughey, Anne Hathaway, Jessica Ch...  2014
# 96   Ryûnosuke Kamiki, Mone Kamishiraishi, Ryô Nari...  2016
# 249  François Cluzet, Omar Sy, Anne Le Ny, Audrey F...  2011
# 64   Christian Bale, Hugh Jackman, Scarlett Johanss...  2006
# 991  Darsheel Safary, Aamir Khan, Tanay Chheda, Sac...  2007
# 476  Ulrich Mühe, Martina Gedeck,Sebastian Koch, Ul...  2006
# 124  Christian Bale, Tom Hardy, Anne Hathaway,Gary ...  2012
#
#      Runtime (Minutes)  Rating    Votes  Revenue (Millions)  Metascore
# 54                 152     9.0  1791916              533.32       82.0
# 117                161     8.8    48969               11.15        NaN
# 80                 148     8.8  1583625              292.57       74.0
# 36                 169     8.6  1047747              187.99       74.0
# 96                 106     8.6    34110                4.68       79.0
# 249                112     8.6   557965               13.18       57.0
# 64                 130     8.5   913152               53.08       66.0
# 991                165     8.5   102697                1.20       42.0
# 476                137     8.5   278103               11.28       89.0
# 124                164     8.5  1222645              448.13       78.0

# %% [markdown]
# In the cell below we are filling the new ranks in the `Rank` column of the DataFrame with the numerical data rank along axis.
#
# Equal values are assigned a rank that is the average of the ranks of those values.

# %%
# Filling the new rank column with the sorted values
df['Rank'] = df['Rating'].rank(ascending=False)

df.head(10)
# Out:
#      Rank                  Title                    Genre  \
# 54    1.0        The Dark Knight       Action,Crime,Drama
# 117   2.5                 Dangal   Action,Biography,Drama
# 80    2.5              Inception  Action,Adventure,Sci-Fi
# 36    5.0           Interstellar   Adventure,Drama,Sci-Fi
# 96    5.0          Kimi no na wa  Animation,Drama,Fantasy
# 249   5.0       The Intouchables   Biography,Comedy,Drama
# 64    9.5           The Prestige     Drama,Mystery,Sci-Fi
# 991   9.5       Taare Zameen Par       Drama,Family,Music
# 476   9.5    The Lives of Others           Drama,Thriller
# 124   9.5  The Dark Knight Rises          Action,Thriller
#
#                                            Description  \
# 54   When the menace known as the Joker wreaks havo...
# 117  Former wrestler Mahavir Singh Phogat and his t...
# 80   A thief, who steals corporate secrets through ...
# 36   A team of explorers travel through a wormhole ...
# 96   Two strangers find themselves linked in a biza...
# 249  After he becomes a quadriplegic from a paragli...
# 64   Two stage magicians engage in competitive one-...
# 991  An eight-year-old boy is thought to be a lazy ...
# 476  In 1984 East Berlin, an agent of the secret po...
# 124  Eight years after the Joker's reign of anarchy...
#
#                              Director  \
# 54                  Christopher Nolan
# 117                     Nitesh Tiwari
# 80                  Christopher Nolan
# 36                  Christopher Nolan
# 96                     Makoto Shinkai
# 249                   Olivier Nakache
# 64                  Christopher Nolan
# 991                        Aamir Khan
# 476  Florian Henckel von Donnersmarck
# 124                 Christopher Nolan
#
#                                                 Actors  Year  \
# 54   Christian Bale, Heath Ledger, Aaron Eckhart,Mi...  2008
# 117  Aamir Khan, Sakshi Tanwar, Fatima Sana Shaikh,...  2016
# 80   Leonardo DiCaprio, Joseph Gordon-Levitt, Ellen...  2010
# 36   Matthew McConaughey, Anne Hathaway, Jessica Ch...  2014
# 96   Ryûnosuke Kamiki, Mone Kamishiraishi, Ryô Nari...  2016
# 249  François Cluzet, Omar Sy, Anne Le Ny, Audrey F...  2011
# 64   Christian Bale, Hugh Jackman, Scarlett Johanss...  2006
# 991  Darsheel Safary, Aamir Khan, Tanay Chheda, Sac...  2007
# 476  Ulrich Mühe, Martina Gedeck,Sebastian Koch, Ul...  2006
# 124  Christian Bale, Tom Hardy, Anne Hathaway,Gary ...  2012
#
#      Runtime (Minutes)  Rating    Votes  Revenue (Millions)  Metascore
# 54                 152     9.0  1791916              533.32       82.0
# 117                161     8.8    48969               11.15        NaN
# 80                 148     8.8  1583625              292.57       74.0
# 36                 169     8.6  1047747              187.99       74.0
# 96                 106     8.6    34110                4.68       79.0
# 249                112     8.6   557965               13.18       57.0
# 64                 130     8.5   913152               53.08       66.0
# 991                165     8.5   102697                1.20       42.0
# 476                137     8.5   278103               11.28       89.0
# 124                164     8.5  1222645              448.13       78.0

# %% [markdown]
# Filling missing values in the 'Metascore' column with the mean of the column

# %%
df['Metascore'].fillna(df['Metascore'].mean(), inplace=True)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 970 entries, 54 to 829
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                970 non-null    float64
#  1   Title               970 non-null    object
#  2   Genre               970 non-null    object
#  3   Description         970 non-null    object
#  4   Director            970 non-null    object
#  5   Actors              970 non-null    object
#  6   Year                970 non-null    int64
#  7   Runtime (Minutes)   970 non-null    int64
#  8   Rating              970 non-null    float64
#  9   Votes               970 non-null    int64
#  10  Revenue (Millions)  970 non-null    float64
#  11  Metascore           970 non-null    float64
# dtypes: float64(4), int64(3), object(5)
# memory usage: 98.5+ KB

# %% [markdown]
# Normalizing the data in the `Metascore` column and reporting the mean and standard deviation of the column before and after normalization.
#
# as we can see the mean and standard deviation of the column after normalization is approx. 0 and 1 respectively.

# %%
print("Mean before normalization: ", df['Metascore'].mean())
print("Standard deviation before normalization: ", df['Metascore'].std())

scaler = StandardScaler()
df['Metascore'] = scaler.fit_transform(df['Metascore'].values.reshape(-1, 1))

print("Mean after normalization: ", df['Metascore'].mean())
print("Standard deviation after normalization: ", df['Metascore'].std())
# Out:
# Mean before normalization:  58.98504273504268
# Standard deviation before normalization:  16.890400990274657
# Mean after normalization:  9.614302481290015e-18
# Standard deviation after normalization:  1.0005158628148114

# %% [markdown]
# Finding the Number of movies that Christopher Nolan directed.

# %%
christopher_nolan_movies = df[df['Director'] == 'Christopher Nolan']

christopher_nolan_movies.head(10)
# Out:
#      Rank                  Title                    Genre  \
# 54    1.0        The Dark Knight       Action,Crime,Drama
# 80    2.5              Inception  Action,Adventure,Sci-Fi
# 36    5.0           Interstellar   Adventure,Drama,Sci-Fi
# 64    9.5           The Prestige     Drama,Mystery,Sci-Fi
# 124   9.5  The Dark Knight Rises          Action,Thriller
#
#                                            Description           Director  \
# 54   When the menace known as the Joker wreaks havo...  Christopher Nolan
# 80   A thief, who steals corporate secrets through ...  Christopher Nolan
# 36   A team of explorers travel through a wormhole ...  Christopher Nolan
# 64   Two stage magicians engage in competitive one-...  Christopher Nolan
# 124  Eight years after the Joker's reign of anarchy...  Christopher Nolan
#
#                                                 Actors  Year  \
# 54   Christian Bale, Heath Ledger, Aaron Eckhart,Mi...  2008
# 80   Leonardo DiCaprio, Joseph Gordon-Levitt, Ellen...  2010
# 36   Matthew McConaughey, Anne Hathaway, Jessica Ch...  2014
# 64   Christian Bale, Hugh Jackman, Scarlett Johanss...  2006
# 124  Christian Bale, Tom Hardy, Anne Hathaway,Gary ...  2012
#
#      Runtime (Minutes)  Rating    Votes  Revenue (Millions)  Metascore
# 54                 152     9.0  1791916              533.32   1.363309
# 80                 148     8.8  1583625              292.57   0.889423
# 36                 169     8.6  1047747              187.99   0.889423
# 64                 130     8.5   913152               53.08   0.415536
# 124                164     8.5  1222645              448.13   1.126366

# %% [markdown]
# Finding the Number of movies that has a rating greater than 8.4 and smaller than 8.6

# %%
target_movies = df[(df['Rating'] >= 8.4) & (df['Rating'] <= 8.6)]

target_movies.head()
# Out:
#      Rank             Title                    Genre  \
# 36    5.0      Interstellar   Adventure,Drama,Sci-Fi
# 96    5.0     Kimi no na wa  Animation,Drama,Fantasy
# 249   5.0  The Intouchables   Biography,Comedy,Drama
# 64    9.5      The Prestige     Drama,Mystery,Sci-Fi
# 991   9.5  Taare Zameen Par       Drama,Family,Music
#
#                                            Description           Director  \
# 36   A team of explorers travel through a wormhole ...  Christopher Nolan
# 96   Two strangers find themselves linked in a biza...     Makoto Shinkai
# 249  After he becomes a quadriplegic from a paragli...    Olivier Nakache
# 64   Two stage magicians engage in competitive one-...  Christopher Nolan
# 991  An eight-year-old boy is thought to be a lazy ...         Aamir Khan
#
#                                                 Actors  Year  \
# 36   Matthew McConaughey, Anne Hathaway, Jessica Ch...  2014
# 96   Ryûnosuke Kamiki, Mone Kamishiraishi, Ryô Nari...  2016
# 249  François Cluzet, Omar Sy, Anne Le Ny, Audrey F...  2011
# 64   Christian Bale, Hugh Jackman, Scarlett Johanss...  2006
# 991  Darsheel Safary, Aamir Khan, Tanay Chheda, Sac...  2007
#
#      Runtime (Minutes)  Rating    Votes  Revenue (Millions)  Metascore
# 36                 169     8.6  1047747              187.99   0.889423
# 96                 106     8.6    34110                4.68   1.185601
# 249                112     8.6   557965               13.18  -0.117586
# 64                 130     8.5   913152               53.08   0.415536
# 991                165     8.5   102697                1.20  -1.006122

# %% [markdown]
# Showing the imbd score versus the metascore of the movies in a plot.

# %%
df.plot(x='Metascore', y='Rating', kind='scatter', title='IMDB Score vs Metascore', figsize=(10, 5), color='green', alpha=0.5, grid=True)
# Out:
# <AxesSubplot:title={'center':'IMDB Score vs Metascore'}, xlabel='Metascore', ylabel='Rating'>

# %% [markdown]
# Finding all the movies before 2013, shorter than 100 minutes, but longer than 85 minutes.

# %%
target_movies = df[(df['Year'] < 2013) & (df['Runtime (Minutes)'] > 85) & (df['Runtime (Minutes)'] < 100)]

target_movies.head()
# Out:
#      Rank                     Title                       Genre  \
# 634  14.5                    WALL·E  Animation,Adventure,Family
# 499  20.0                        Up  Animation,Adventure,Comedy
# 695  46.0       Hachi: A Dog's Tale                Drama,Family
# 772  46.0  How to Train Your Dragon  Animation,Action,Adventure
# 598  88.5                      Moon        Drama,Mystery,Sci-Fi
#
#                                            Description         Director  \
# 634  In the distant future, a small waste-collectin...   Andrew Stanton
# 499  Seventy-eight year old Carl Fredricksen travel...      Pete Docter
# 695  A college professor's bond with the abandoned ...  Lasse Hallström
# 772  A hapless young Viking who aspires to hunt dra...     Dean DeBlois
# 598  Astronaut Sam Bell has a quintessentially pers...     Duncan Jones
#
#                                                 Actors  Year  \
# 634  Ben Burtt, Elissa Knight, Jeff Garlin, Fred Wi...  2008
# 499  Edward Asner, Jordan Nagai, John Ratzenberger,...  2009
# 695  Richard Gere, Joan Allen, Cary-Hiroyuki Tagawa...  2009
# 772  Jay Baruchel, Gerard Butler,Christopher Mintz-...  2010
# 598  Sam Rockwell, Kevin Spacey, Dominique McElligo...  2009
#
#      Runtime (Minutes)  Rating   Votes  Revenue (Millions)  Metascore
# 634                 98     8.4  776897          223.810000   0.000000
# 499                 96     8.3  722203          292.980000   1.718723
# 695                 93     8.1  177602           82.956376   0.119358
# 772                 98     8.1  523893          217.390000   0.889423
# 598                 97     7.9  277123            5.010000   0.474772

# %% [markdown]
# # Thanks for reading my notebook :)
